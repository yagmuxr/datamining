# %%
#Hipotez testleri

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

df_sleep = pd.read_csv("data/msleep.csv")

sns.scatterplot(x="sleep_total",y="sleep_rem",data=df_sleep)
# Out:
# <Axes: xlabel='sleep_total', ylabel='sleep_rem'>

# %%
df_sleep["sleep_total"].corr(df_sleep["sleep_rem"])
# Out:
# 0.7517549992287144

# %%
sns.lmplot(x="sleep_total",y="sleep_rem",data = df_sleep, ci=95)

# %%
sns.scatterplot(x="brainwt",y="bodywt",data=df_sleep)
# Out:
# <Axes: xlabel='brainwt', ylabel='bodywt'>

# %%
df_sleep_corr=df_sleep.corr(numeric_only=True)
df_sleep_corr
# Out:
#              sleep_total  sleep_rem  sleep_cycle     awake   brainwt    bodywt
# sleep_total     1.000000   0.751755    -0.473713 -0.999999 -0.360487 -0.312011
# sleep_rem       0.751755   1.000000    -0.338123 -0.751771 -0.221335 -0.327651
# sleep_cycle    -0.473713  -0.338123     1.000000  0.473713  0.851620  0.417803
# awake          -0.999999  -0.751771     0.473713  1.000000  0.360487  0.311980
# brainwt        -0.360487  -0.221335     0.851620  0.360487  1.000000  0.933782
# bodywt         -0.312011  -0.327651     0.417803  0.311980  0.933782  1.000000

# %%
sns.heatmap(df_sleep_corr,annot=True,cmap='crest')
# Out:
# <Axes: >
